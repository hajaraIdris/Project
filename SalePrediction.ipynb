# %% [markdown]
# <a href="https://colab.research.google.com/github/hajaraIdris/Project/blob/main/SalePrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Sales Prediction***
# ***Advertisement Sales Predition from an existing customers***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-18c992c0-1900-4a91-a9d8-45a7031126db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-18c992c0-1900-4a91-a9d8-45a7031126db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset=pd.read_csv('Customer_Data_Bike.csv')
dataset.head()
# Out:
#    Age  Income Purchased Bike
# 0   42   40000             No
# 1   43   30000             No
# 2   60   80000             No
# 3   41   70000            Yes
# 4   36   30000            Yes

# %%
dataset.tail()
# Out:
#      Age  Income Purchased Bike
# 995   54   60000            Yes
# 996   35   70000            Yes
# 997   38   60000            Yes
# 998   38  100000             No
# 999   53   60000            Yes

# %%
dataset.shape
# Out:
# (1000, 3)

# %%
dataset.describe(include='all')
# Out:
#                 Age         Income Purchased Bike
# count   1000.000000    1000.000000           1000
# unique          NaN            NaN              2
# top             NaN            NaN             No
# freq            NaN            NaN            519
# mean      44.163000   56360.000000            NaN
# std       11.364488   31085.635215            NaN
# min       25.000000   10000.000000            NaN
# 25%       35.000000   30000.000000            NaN
# 50%       43.000000   60000.000000            NaN
# 75%       52.000000   70000.000000            NaN
# max       89.000000  170000.000000            NaN

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             1000 non-null   int64
#  1   Income          1000 non-null   int64
#  2   Purchased Bike  1000 non-null   object
# dtypes: int64(2), object(1)
# memory usage: 23.6+ KB

# %% [markdown]
# # **Data Segregation**

# %%
x=dataset.iloc[:,:-1].values
x[0:5]
# Out:
# array([[   42, 40000],
#        [   43, 30000],
#        [   60, 80000],
#        [   41, 70000],
#        [   36, 30000]])

# %%
y=dataset.iloc[:,-1].values
y[0:5]
# Out:
# array(['No', 'No', 'No', 'Yes', 'Yes'], dtype=object)

# %% [markdown]
# #**Split the dataset into train and test data**

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train, y_test=train_test_split(x,y,test_size= 0.2, random_state=0)

# %%
(x_train.shape, y_train.shape), (x_test.shape, y_test.shape)
# Out:
# (((800, 2), (800,)), ((200, 2), (200,)))

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# **Predicting whether a new customer with Age and Income , would purchase the bike or not**.

# %%
Age=int(input('Enter the new customer age:'))
Income=int(input('Enter new customer income:'))
newCust=[[Age,Income]]
result=model.predict(sc.transform(newCust))
print(result)
# Out:
# Enter the new customer age:35
# Enter new customer income:1000
# ['No']
